# %%
import pandas as pd
data=pd.read_csv("C:/Users/SUMEDHA HEMADRI/Downloads/netflix_titles.csv.zip")

# %%
print(data.isnull().sum())
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
data=data.dropna()

# %%
data["show_id"].fillna("Null")
data
# Out:
#      show_id     type       title           director  \
# 1         s2    Movie        7:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7778   s7779    Movie  Zombieland    Ruben Fleischer
# 7780   s7781    Movie         Zoo       Shlok Sharma
# 7781   s7782    Movie        Zoom       Peter Hewitt
# 7782   s7783    Movie        Zozo        Josef Fares
# 7783   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
data=data.drop_duplicates()
data
# Out:
#      show_id     type       title           director  \
# 1         s2    Movie        7:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7778   s7779    Movie  Zombieland    Ruben Fleischer
# 7780   s7781    Movie         Zoo       Shlok Sharma
# 7781   s7782    Movie        Zoom       Peter Hewitt
# 7782   s7783    Movie        Zozo        Josef Fares
# 7783   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
data["director"]=data["director"].str.lower()
data
# Out:
#      show_id     type       title           director  \
# 1         s2    Movie        7:19  jorge michel grau
# 2         s3    Movie       23:59       gilbert chan
# 3         s4    Movie           9        shane acker
# 4         s5    Movie          21     robert luketic
# 5         s6  TV Show          46        serdar akar
# ...      ...      ...         ...                ...
# 7778   s7779    Movie  Zombieland    ruben fleischer
# 7780   s7781    Movie         Zoo       shlok sharma
# 7781   s7782    Movie        Zoom       peter hewitt
# 7782   s7783    Movie        Zozo        josef fares
# 7783   s7784    Movie      Zubaan        mozez singh
#
#                                                    cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
data["country"]=data["country"].replace({"United States":"US","India":"IN"})
data
# Out:
#      show_id     type       title           director  \
# 1         s2    Movie        7:19  jorge michel grau
# 2         s3    Movie       23:59       gilbert chan
# 3         s4    Movie           9        shane acker
# 4         s5    Movie          21     robert luketic
# 5         s6  TV Show          46        serdar akar
# ...      ...      ...         ...                ...
# 7778   s7779    Movie  Zombieland    ruben fleischer
# 7780   s7781    Movie         Zoo       shlok sharma
# 7781   s7782    Movie        Zoom       peter hewitt
# 7782   s7783    Movie        Zozo        josef fares
# 7783   s7784    Movie      Zubaan        mozez singh
#
#                                                    cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
data["date_added"]=pd.to_datetime(data["date_added"],errors="coerce")
data
# Out:
#      show_id     type       title           director  \
# 1         s2    Movie        7:19  jorge michel grau
# 2         s3    Movie       23:59       gilbert chan
# 3         s4    Movie           9        shane acker
# 4         s5    Movie          21     robert luketic
# 5         s6  TV Show          46        serdar akar
# ...      ...      ...         ...                ...
# 7778   s7779    Movie  Zombieland    ruben fleischer
# 7780   s7781    Movie         Zoo       shlok sharma
# 7781   s7782    Movie        Zoom       peter hewitt
# 7782   s7783    Movie        Zozo        josef fares
# 7783   s7784    Movie      Zubaan        mozez singh
#
#                                                    cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
 
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %%
data["release_year"]=data["release_year"].astype(float)
data
# Out:
#      show_id     type       title           director  \
# 1         s2    Movie        7:19  jorge michel grau
# 2         s3    Movie       23:59       gilbert chan
# 3         s4    Movie           9        shane acker
# 4         s5    Movie          21     robert luketic
# 5         s6  TV Show          46        serdar akar
# ...      ...      ...         ...                ...
# 7778   s7779    Movie  Zombieland    ruben fleischer
# 7780   s7781    Movie         Zoo       shlok sharma
# 7781   s7782    Movie        Zoom       peter hewitt
# 7782   s7783    Movie        Zozo        josef fares
# 7783   s7784    Movie      Zubaan        mozez singh
#
#                                                    cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
data.to_csv("cleaned_dataset_given.csv",index=False)
data
# Out:
#      show_id     type       title           director  \
# 1         s2    Movie        7:19  jorge michel grau
# 2         s3    Movie       23:59       gilbert chan
# 3         s4    Movie           9        shane acker
# 4         s5    Movie          21     robert luketic
# 5         s6  TV Show          46        serdar akar
# ...      ...      ...         ...                ...
# 7778   s7779    Movie  Zombieland    ruben fleischer
# 7780   s7781    Movie         Zoo       shlok sharma
# 7781   s7782    Movie        Zoom       peter hewitt
# 7782   s7783    Movie        Zozo        josef fares
# 7783   s7784    Movie      Zubaan        mozez singh
#
#                                                    cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...
